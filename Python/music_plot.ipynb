# %%
import pandas as pd
import matplotlib
import japanize_matplotlib

# %%
df = pd.read_csv('./csv/ave_data.csv', index_col=0)
df.head()
# Out:
#           平均再生数         BPM    曲の長さ(ms)      ラウド感       dB値     曲の明るさ  \
# 2019  16476.250  119.949365  246921.765  0.720050 -4.904325  0.534535
# 2020  39275.485  124.040810  247737.295  0.738170 -4.553985  0.574185
# 2021  65238.655  120.707135  236898.400  0.725005 -4.850490  0.592392
# 2022  62781.345  126.482710  238105.120  0.736745 -4.776240  0.601285
# 2023  78572.235  128.214720  225575.680  0.755505 -4.664725  0.625633
#
#           ダンス感  アコースティック感     言葉の密度     インスト度
# 2019  0.588610   0.197022  0.061881  0.005405
# 2020  0.594005   0.181162  0.059609  0.007310
# 2021  0.614095   0.171076  0.065349  0.000606
# 2022  0.611170   0.176860  0.060999  0.004217
# 2023  0.616520   0.155457  0.066841  0.004360

# %%
df.plot(subplots=True, layout=(5,2), figsize=(8.27,11.69), sharex=False, alpha=0.6, style='-o', grid=True, \
    title='2019年 - 2023年 6月9日の楽曲データ平均値'
)
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)
